# %% [markdown]
# Assignment Day 2

# %%
print("hello python")
# Out:
# hello python

# %%
print("hello \
Python")
# Out:
# hello Python

# %%
print(""" This program is written by Sourabh """)
# Out:
#  This program is written by Sourabh

# %%
print('hello world')
# Out:
# hello world

# %%
print('sourabh's class')
# Out:
#   File "<ipython-input-10-21a96fac2888>", line 1
#     print('sourabh's class')
#                    ^
# SyntaxError: invalid syntax

# %%
print("sourabh's class")
# Out:
# sourabh's class

# %%
print(" hello \tworld")
# Out:
#  hello 	world

# %%
print(" hello \nworld")
# Out:
#  hello
# world

# %%
print('sourabh\'s class')
# Out:
# sourabh's class

# %%
name= "sourabh"
marks= "95.423"
age= "20"
print("The name of person is" ,name,"marks are",marks, "and age is",age)
# Out:
# The name of person is sourabh marks are 95.423 and age is 20

# %%
print(f" The name of person is{name} marks are {marks} and age is {age}")
# Out:
#  The name of person isxyz marks are 95 and age is 20

# %%
x= 20
id(x)
# Out:
# 10915104

# %%
y= 20
id(y)
# Out:
# 10915104

# %%
10**3
# Out:
# 1000

# %%
50+20
# Out:
# 70

# %%
40/4
# Out:
# 10.0

# %%
20/6
# Out:
# 3.3333333333333335

# %%
20//6
# Out:
# 3

# %%
a=10
b=20
a==b
# Out:
# False

# %%
c=10
a==c
# Out:
# True

# %%
c<=a
# Out:
# True

# %%
a!=b
# Out:
# True

# %%
b<=a
# Out:
# False

# %%
a=10
b=20
a+=b

# %%
a=240
b=1
bin(a)
# Out:
# '0b11110000'

# %%
bin(b)
# Out:
# '0b1'

# %%
a&b
# Out:
# 0

# %%
a|b
# Out:
# 241

# %%
a=10
b=20
a>b
# Out:
# False

# %%
a>b or 10>9
# Out:
# True

# %%
not b>a
# Out:
# False

# %%
not a>b
# Out:
# True

# %%
str1 = "engineering"
"r" in str1
# Out:
# True

# %%
'x' not in str1
# Out:
# True

# %%
a=19
b=19
a==b
# Out:
# True

# %%
a is b
# Out:
# True

# %%
x=258
y=258
x==y
# Out:
# True

# %%
x is y
# Out:
# False

# %%
10/20*4
# Out:
# 2.0

# %%
20//6
# Out:
# 3

# %% [markdown]
# Thank you 😊
